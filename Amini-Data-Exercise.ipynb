# %%
import numpy as np
import pandas as pd

df = pd.read_csv('health_registry.csv')

# %%
print(df)
# Out:
#       facility_id                         facility_name  \
# 0         HF-0000         Burgess-Ingram Medical Center
# 1          033477                           Collins Inc
# 2              #2              Butler-Leon Clinic (St.)
# 3               2              Butler-Leon Clinic (St.)
# 4         HF-0003  Powell, Morales and Butler Infirmary
# ...           ...                                   ...
# 13008         ###                                   NaN
# 13009         NaN                                   NaN
# 13010         NaN                                    --
# 13011         NaN                                    --
# 13012         ???                                   NaN
#
#                facility_type      capacity            region  \
# 0      Community Health Ctr.      250 beds           St.Lucy
# 1                      Hosp.           NaN          St.Peter
# 2                   Hospital       117Beds  St. James Parish
# ...

# %%
df
df.head()
# Out:
#   facility_id                         facility_name          facility_type  \
# 0     HF-0000         Burgess-Ingram Medical Center  Community Health Ctr.
# 1      033477                           Collins Inc                  Hosp.
# 2          #2              Butler-Leon Clinic (St.)               Hospital
# 3           2              Butler-Leon Clinic (St.)               Hospital
# 4     HF-0003  Powell, Morales and Butler Infirmary            Health Ctr.
#
#        capacity            region licence_issue_date inspection_date  \
# 0      250 beds           St.Lucy           04-01-21     08 Mar 2024
# 1           NaN          St.Peter        28 Mar 2024        17-04-23
# 2       117Beds  St. James Parish         2016-02-18        30/12/22
# 3       117Beds  St. James Parish         2016-02-18        30/12/22
# 4  179 capacity          ST. LUCY   November 21 2020        07-03-24
#
#                 gps_location         remarks
# 0        13.08576, -58.75331             NaN
# ...

# %%
df.describe(include="all") #statistical information
# Out:
#        facility_id facility_name            facility_type capacity  \
# count         9305         12989                    11015    10361
# unique        7356         10233                       11     2904
# top            ???            --  Community Health Centre  unknown
# freq            16            14                     1060     1403
#
#                region licence_issue_date inspection_date gps_location  \
# count           12980              12990           13002        10721
# unique            116               7980            7509         8282
# top     Christ Church           32/13/99        32/13/99    somewhere
# freq              363                124             135           22
#
#                  remarks
# count              10080
# unique                 8
# top     Reinspection due
# freq                1503

# %%
df.isna().sum() #total amount missing
# Out:
# facility_id           3708
# facility_name           24
# facility_type         1998
# capacity              2652
# region                  33
# licence_issue_date      23
# inspection_date         11
# gps_location          2292
# remarks               2933
# dtype: int64

# %%
df.isna().mean() * 100  # percentage missing
# Out:
# facility_id           28.494582
# facility_name          0.184431
# facility_type         15.353877
# capacity              20.379620
# region                 0.253593
# licence_issue_date     0.176746
# inspection_date        0.084531
# gps_location          17.613156
# remarks               22.538999
# dtype: float64

# %%
df.columns.values
# Out:
# array(['facility_id', 'facility_name', 'facility_type', 'capacity',
#        'region', 'licence_issue_date', 'inspection_date', 'gps_location',
#        'remarks'], dtype=object)

# %%
df.nunique()
df["facility_id"].value_counts()
# Out:
# facility_id
# ???       16
# ###        9
# 7d10f8     2
# b4213f     2
# 7703       2
#           ..
# #3872      1
# 65622f     1
# 03866      1
# #3865      1
# 5019       1
# Name: count, Length: 7356, dtype: int64

# %%
from ydata_profiling import ProfileReport

# %%
profile = ProfileReport(df, title="Data Profile", explorative=True)
profile.to_file("report.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
#Report generated that summarizes the data found.

# %%
df.duplicated().sum()
df = df.drop_duplicates()
df
# Out:
#       facility_id                         facility_name  \
# 0         HF-0000         Burgess-Ingram Medical Center
# 1          033477                           Collins Inc
# 2              #2              Butler-Leon Clinic (St.)
# 3               2              Butler-Leon Clinic (St.)
# 4         HF-0003  Powell, Morales and Butler Infirmary
# ...           ...                                   ...
# 13008         ###                                   NaN
# 13009         NaN                                   NaN
# 13010         NaN                                    --
# 13011         NaN                                    --
# 13012         ???                                   NaN
#
#                facility_type      capacity            region  \
# 0      Community Health Ctr.      250 beds           St.Lucy
# 1                      Hosp.           NaN          St.Peter
# 2                   Hospital       117Beds  St. James Parish
# ...

# %%
titles = list(df.columns.values)
titles
# Out:
# ['facility_id',
#  'facility_name',
#  'facility_type',
#  'capacity',
#  'region',
#  'licence_issue_date',
#  'inspection_date',
#  'gps_location',
#  'remarks']

# %%
df["licence_issue_date"] = pd.to_datetime(df["licence_issue_date"], errors="coerce", format="mixed")
df["inspection_date"] = pd.to_datetime(df["inspection_date"], errors="coerce", format="mixed")  #change the dates
# Out:
# C:\Users\IanSF\AppData\Local\Temp\ipykernel_17188\3842305306.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["licence_issue_date"] = pd.to_datetime(df["licence_issue_date"], errors="coerce", format="mixed")
# C:\Users\IanSF\AppData\Local\Temp\ipykernel_17188\3842305306.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["inspection_date"] = pd.to_datetime(df["inspection_date"], errors="coerce", format="mixed")  #change the dates

# %%
df
# Out:
#       facility_id                         facility_name  \
# 0         HF-0000         Burgess-Ingram Medical Center
# 1          033477                           Collins Inc
# 2              #2              Butler-Leon Clinic (St.)
# 3               2              Butler-Leon Clinic (St.)
# 4         HF-0003  Powell, Morales and Butler Infirmary
# ...           ...                                   ...
# 13008         ###                                   NaN
# 13009         NaN                                   NaN
# 13010         NaN                                    --
# 13011         NaN                                    --
# 13012         ???                                   NaN
#
#                facility_type      capacity            region  \
# 0      Community Health Ctr.      250 beds           St.Lucy
# 1                      Hosp.           NaN          St.Peter
# 2                   Hospital       117Beds  St. James Parish
# ...

# %%
#now to get capacity

# %%
import re

# %%
df["capacity"] = df.capacity.str.extract(r'(\d+)')
# Out:
# C:\Users\IanSF\AppData\Local\Temp\ipykernel_17188\1372316370.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["capacity"] = df.capacity.str.extract(r'(\d+)')

# %%
df
# Out:
#       facility_id                         facility_name  \
# 0         HF-0000         Burgess-Ingram Medical Center
# 1          033477                           Collins Inc
# 2              #2              Butler-Leon Clinic (St.)
# 3               2              Butler-Leon Clinic (St.)
# 4         HF-0003  Powell, Morales and Butler Infirmary
# ...           ...                                   ...
# 13008         ###                                   NaN
# 13009         NaN                                   NaN
# 13010         NaN                                    --
# 13011         NaN                                    --
# 13012         ???                                   NaN
#
#                facility_type capacity            region licence_issue_date  \
# 0      Community Health Ctr.      250           St.Lucy         2021-04-01
# 1                      Hosp.      NaN          St.Peter         2024-03-28
# ...

# %%
df
# Out:
#       facility_id                         facility_name  \
# 0         HF-0000         Burgess-Ingram Medical Center
# 1          033477                           Collins Inc
# 2              #2              Butler-Leon Clinic (St.)
# 3               2              Butler-Leon Clinic (St.)
# 4         HF-0003  Powell, Morales and Butler Infirmary
# ...           ...                                   ...
# 13008         ###                                   NaN
# 13009         NaN                                   NaN
# 13010         NaN                                    --
# 13011         NaN                                    --
# 13012         ???                                   NaN
#
#                facility_type capacity            region licence_issue_date  \
# 0      Community Health Ctr.      250           St.Lucy         2021-04-01
# 1                      Hosp.      NaN          St.Peter         2024-03-28
# ...
